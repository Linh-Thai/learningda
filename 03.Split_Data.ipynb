# %%
import pandas as pd, numpy as np
import sys, os
from pprint import pprint
import random
from datetime import datetime, timedelta

# %%
import re

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
def print_runtime():
    print(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    print("-"*19)
print_runtime()
# Out:
# 2021-09-19 14:23:39
# -------------------

# %% [markdown]
# # TODO: Split quiz_result_history into smaller table

# %%
quiz = (
    '{"0":{"id":"107","excerpt":"T\u1eeb n\u0103m 2003 \u0111\u1ebfn nay \u0110\u1ea3ng \u0111\u00e3 bao nhi\u00eau l\u1ea7n ban h\u00e0nh Ch\u1ec9 th\u1ecb v\u1ec1 h\u1ecdc t\u1eadp v\u00e0 l\u00e0m theo B\u00e1c:","image":null,"sound":null,"youtube":null,"answer":{"wqmm":"04 l\u1ea7n","daff":"2 l\u1ea7n","nkxi":"5 l\u1ea7n","xvyx":"3 l\u1ea7n"},"true":["wqmm"]},'
    '"2":{"id":"109","excerpt":"Theo ch\u1ec9 th\u1ecb s\u1ed1 05-CT\/TW ng\u00e0y 15\/5\/2016 c\u1ee7a B\u1ed9 Ch\u00ednh tr\u1ecb, \u0111\u01b0a vi\u1ec7c h\u1ecdc t\u1eadp v\u00e0 l\u00e0m theo t\u01b0 t\u01b0\u1edfng, \u0111\u1ea1o \u0111\u1ee9c, phong c\u00e1ch H\u1ed3 Ch\u00ed Minh v\u00e0o n\u1ed9i dung sinh ho\u1ea1t th\u01b0\u1eddng xuy\u00ean c\u1ee7a t\u1ed5 ch\u1ee9c \u0111\u1ea3ng n\u00e0o?","image":null,"sound":null,"youtube":null,"answer":{"zxpm":"Qu\u1eadn, Huy\u1ec7n, Th\u1ecb u\u1ef7","tqyh":"T\u1ed5 ch\u1ee9c c\u01a1 s\u1edf \u0111\u1ea3ng","ojjn":"Chi b\u1ed9","arnw":"T\u1ec9nh, Th\u00e0nh u\u1ef7"},"true":["ojjn"]},'
    '"24":{"id":"131","excerpt":"C\u00f3 bao nhi\u00eau h\u1ea1n ch\u1ebf, khuy\u1ebft \u0111i\u1ec3m'
    ' qua 5 n\u0103m th\u1ef1c hi\u1ec7n Ngh\u1ecb quy\u1ebft \u0110\u1ea1i h\u1ed9i XII c\u1ee7a'
    ' \u0110\u1ea3ng \u0111\u01b0\u1ee3c ch\u1ec9 ra trong B\u00e1o c\u00e1o ch\u00ednh tr\u1ecb'
    ' c\u1ee7a Ban Ch\u1ea5p h\u00e0nh Trung \u01b0\u01a1ng \u0110\u1ea3ng kh\u00f3a XII t\u1ea1i'
    ' \u0110\u1ea1i h\u1ed9i \u0111\u1ea1i bi\u1ec3u to\u00e0n qu\u1ed1c l\u1ea7n th\u1ee9 XIII'
    ' c\u1ee7a \u0110\u1ea3ng?","image":null,"sound":null,"youtube":null,'
    '"answer":{"yaln":"6","jnec":"7","zpyb":"8","ibnl":"9"},"true":["zpyb"]},'
    '"28":{"id":"135","excerpt":"\u0110\u1ea1i h\u1ed9i XIII c\u1ee7a \u0110\u1ea3ng \u0111\u00e1nh'
    '"131":{"id":"260","excerpt":"T\u1ef7 tr\u1ecdng c\u00e1c ng\u00e0nh c\u00f4ng nghi\u1ec7p \u2013 x\u00e2y d\u1ef1ng, d\u1ecbch v\u1ee5 - th\u01b0\u01a1ng m\u1ea1i chi\u1ebfm bao nhi\u00eau ph\u1ea7n tr\u0103m theo Ngh\u1ecb quy\u1ebft \u0110\u1ea1i h\u1ed9i \u0111\u1ea1i bi\u1ec3u \u0110\u1ea3ng b\u1ed9 qu\u1eadn L\u00ea Ch\u00e2n l\u1ea7n th\u1ee9 XXIV, nhi\u1ec7m k\u1ef3 2020 - 2025 \u0111\u1ec1 ra?","image":null,"sound":null,"youtube":null,"answer":{"hrbo":"Ng\u00e0nh c\u00f4ng nghi\u1ec7p - x\u00e2y d\u1ef1ng chi\u1ebfm 20%, ng\u00e0nh d\u1ecbch v\u1ee5 - th\u01b0\u01a1ng m\u1ea1i chi\u1ebfm 80%","yfxx":"Ng\u00e0nh c\u00f4ng nghi\u1ec7p \u2013 x\u00e2y d\u1ef1ng chi\u1ebfm 80%, ng\u00e0nh d\u1ecbch v\u1ee5 - th\u01b0\u01a1ng m\u1ea1i chi\u1ebfm 20%","mluo":"Ng\u00e0nh c\u00f4ng nghi\u1ec7p \u2013 x\u00e2y d\u1ef1ng chi\u1ebfm 30%, ng\u00e0nh d\u1ecbch v\u1ee5 - th\u01b0\u01a1ng m\u1ea1i chi\u1ebfm 70%","akry":"Ng\u00e0nh c\u00f4ng nghi\u1ec7p \u2013 x\u00e2y d\u1ef1ng chi\u1ebfm 70%, ng\u00e0nh d\u1ecbch v\u1ee5 - th\u01b0\u01a1ng m\u1ea1i chi\u1ebfm 30%"},"true":["hrbo"]}}'
)

# %%
answers = (
    '{"24":["zpyb"],'
    '"0":["wqmm"],'
    '"110":["vbga"],'
    '"44":["ynqg"],'
    '"32":["bjkt"],'
    '"124":["excy"],'
    '"75":["sdwu"],'
    '"28":["hwnk"],'
    '"41":["hrua"],'
    '"39":["cukt"],'
    '"118":["qfeu"],'
    '"76":["wjms"],'
    '"131":["hrbo"],'
    '"122":["xytl"],'
    '"109":["kzpv"],'
    '"130":["hrty"],'
    '"2":["ojjn"],'
    '"97":["pzje"],'
    '"30":["mcsy"],'
    '"74":["rppc"]}'
)

# %%
# "answer":{"wqmm":"04 l\u1ea7n","daff":"2 l\u1ea7n","nkxi":"5 l\u1ea7n","xvyx":"3 l\u1ea7n"}
regex_choice = re.compile("\"answer\":\{(.*?)\}")
ls_choice = regex_choice.findall(quiz)
pprint(ls_choice)
print_runtime()
# Out:
# ['"wqmm":"04 lần","daff":"2 lần","nkxi":"5 lần","xvyx":"3 lần"',
#  '"zxpm":"Quận, Huyện, Thị uỷ","tqyh":"Tổ chức cơ sở đảng","ojjn":"Chi '
#  'bộ","arnw":"Tỉnh, Thành uỷ"',
#  '"yaln":"6","jnec":"7","zpyb":"8","ibnl":"9"',
#  '"kyha":"Đất nước ta chưa bao giờ có được cơ đồ, vị thế và uy tín quốc tế như '
#  'ngày nay.","fuje":"Đất nước ta chưa bao giờ có được cơ đồ, tiềm lực và uy '
#  'tín quốc tế như ngày nay.","tlai":"Đất nước ta chưa bao giờ có được tiềm '
#  'lực, vị thế và uy tín quốc tế như ngày nay.","hwnk":"Đất nước ta chưa bao '
#  'giờ có được cơ đồ, tiềm lực, vị thế và uy tín quốc tế như ngày nay."',
#  '"nneb":"Ngày 23\\/01\\/2019","mcsy":"Ngày 24\\/01\\/2019","lhvk":"Ngày '
#  '18\\/7\\/2019","gfjj":"Ngày 24\\/01\\/2020"',
#  '"bjkt":"4 mục đích, yêu cầu","qvkj":"5  mục đích, yêu cầu","pfox":"6 mục '
#  'đích, yêu cầu","vetj":"3 mục đích, yêu cầu"',
#  '"cukt":"Trên 70%","ffud":"Khoảng 75%","msfp":"Trên 80%","vehb":"Trên 60%"',
# ...

# %%
# answer_id, question_id, answer_val, Correct/Incorrect, },"true":["qfeu"]
# Exams ~ quiz_result: Essay, Essay_answer
regex = re.compile("\"(\d{1,9})\":\{\"id\":\"(\d{1,9})\",\"excerpt.*?\"answer\":\{(.*?)\},\"true\":\[\"([a-z]{4})")
ls_match = regex.findall(quiz)
pprint(ls_match)
print_runtime()
# Out:
# [('0',
#   '107',
#   '"wqmm":"04 lần","daff":"2 lần","nkxi":"5 lần","xvyx":"3 lần"',
#   'wqmm'),
#  ('2',
#   '109',
#   '"zxpm":"Quận, Huyện, Thị uỷ","tqyh":"Tổ chức cơ sở đảng","ojjn":"Chi '
#   'bộ","arnw":"Tỉnh, Thành uỷ"',
#   'ojjn'),
#  ('24', '131', '"yaln":"6","jnec":"7","zpyb":"8","ibnl":"9"', 'zpyb'),
#  ('28',
#   '135',
#   '"kyha":"Đất nước ta chưa bao giờ có được cơ đồ, vị thế và uy tín quốc tế '
#   'như ngày nay.","fuje":"Đất nước ta chưa bao giờ có được cơ đồ, tiềm lực và '
#   'uy tín quốc tế như ngày nay.","tlai":"Đất nước ta chưa bao giờ có được tiềm '
#   'lực, vị thế và uy tín quốc tế như ngày nay.","hwnk":"Đất nước ta chưa bao '
#   'giờ có được cơ đồ, tiềm lực, vị thế và uy tín quốc tế như ngày nay."',
#   'hwnk'),
#  ('30',
#   '137',
#   '"nneb":"Ngày 23\\/01\\/2019","mcsy":"Ngày 24\\/01\\/2019","lhvk":"Ngày '
#   '18\\/7\\/2019","gfjj":"Ngày 24\\/01\\/2020"',
#   'mcsy'),
#  ('32',
#   '139',
# ...

# %%
regex_ans = re.compile("\"(\d{1,9})\":\[\"([a-z]{4})\"")
ls_ans = regex_ans.findall(answers)
pprint(ls_ans)
print_runtime()
# Out:
# [('24', 'zpyb'),
#  ('0', 'wqmm'),
#  ('110', 'vbga'),
#  ('44', 'ynqg'),
#  ('32', 'bjkt'),
#  ('124', 'excy'),
#  ('75', 'sdwu'),
#  ('28', 'hwnk'),
#  ('41', 'hrua'),
#  ('39', 'cukt'),
#  ('118', 'qfeu'),
#  ('76', 'wjms'),
#  ('131', 'hrbo'),
#  ('122', 'xytl'),
#  ('109', 'kzpv'),
#  ('130', 'hrty'),
#  ('2', 'ojjn'),
#  ('97', 'pzje'),
#  ('30', 'mcsy'),
#  ('74', 'rppc')]
# 2021-09-19 14:23:39
# -------------------

# %%
regex_ans = re.compile("\"(\d{1,9})\":\[\"([a-z]{4})\"")
ls_ans = sorted(regex_ans.findall(answers), key=lambda tup: int(tup[0]))
pprint(ls_ans)
print_runtime()
# Out:
# [('0', 'wqmm'),
#  ('2', 'ojjn'),
#  ('24', 'zpyb'),
#  ('28', 'hwnk'),
#  ('30', 'mcsy'),
#  ('32', 'bjkt'),
#  ('39', 'cukt'),
#  ('41', 'hrua'),
#  ('44', 'ynqg'),
#  ('74', 'rppc'),
#  ('75', 'sdwu'),
#  ('76', 'wjms'),
#  ('97', 'pzje'),
#  ('109', 'kzpv'),
#  ('110', 'vbga'),
#  ('118', 'qfeu'),
#  ('122', 'xytl'),
#  ('124', 'excy'),
#  ('130', 'hrty'),
#  ('131', 'hrbo')]
# 2021-09-19 14:23:39
# -------------------

# %%
from operator import itemgetter

# %%
sorted(ls_ans, key=lambda tup: int(tup[0]))
# Out:
# [('0', 'wqmm'),
#  ('2', 'ojjn'),
#  ('24', 'zpyb'),
#  ('28', 'hwnk'),
#  ('30', 'mcsy'),
#  ('32', 'bjkt'),
#  ('39', 'cukt'),
#  ('41', 'hrua'),
#  ('44', 'ynqg'),
#  ('74', 'rppc'),
#  ('75', 'sdwu'),
#  ('76', 'wjms'),
#  ('97', 'pzje'),
#  ('109', 'kzpv'),
#  ('110', 'vbga'),
#  ('118', 'qfeu'),
#  ('122', 'xytl'),
#  ('124', 'excy'),
#  ('130', 'hrty'),
#  ('131', 'hrbo')]

# %%
essay = (
    '{"xcnr":{"limit":"10","excerpt":"H\u00e3y cho bi\u1ebft c\u00f3 bao nhi\u00eau th\u00ed sinh'
    ' c\u00f3 s\u1ed1 \u0111i\u1ec3m l\u00e0m b\u00e0i thi gi\u1ed1ng nh\u01b0 b\u1ea1n?'
    ' (Tr\u1ea3 l\u1eddi b\u1eb1ng s\u1ed1)","answer":"89"}}'
)
print(essay)
regex_essay = re.compile("answer\":\"(\w*)\"\}\}")
essay_ans = regex_essay.findall(essay)
print(essay_ans[0])
print_runtime()
# Out:
# {"xcnr":{"limit":"10","excerpt":"Hãy cho biết có bao nhiêu thí sinh có số điểm làm bài thi giống như bạn? (Trả lời bằng số)","answer":"89"}}
# 89
# 2021-09-19 14:23:39
# -------------------

# %%
def extract_question_answer(quiz, answers):
    # quiz = row["quiz"]
    # answers = row["answers"]
    regex = re.compile(
        "\"(\d{1,9})\":\{\"id\":\"(\d{1,9})\",\"excerpt.*?\"answer\":\{(.*?)\},\"true\":\[\"([a-z]{4})"
    )
    regex_ans = re.compile("\"(\d{1,9})\":\[\"([a-z]{4})\"")
    ls_match = sorted(regex.findall(quiz), key=lambda tup: int(tup[0]))
    ls_ans = sorted(regex_ans.findall(answers), key=lambda tup: int(tup[0]))
    if len(ls_match) != len(ls_ans):
        return []
    ls_output = []
    for match, ans in zip(ls_match, ls_ans):
        # print(match, ans, match[0]==ans[0])
        if match[0] == ans[0]:
            # Match_id, question_id, choice, correct_ans, ans, correct
            ls_output.append((match[0], match[1], match[2], match[3], ans[1], int(match[3]==ans[1])))
    if len(ls_output) != len(ls_match):
        return []
    return ls_output

pprint(extract_question_answer(quiz, answers))
print_runtime()
# Out:
# [('0',
#   '107',
#   '"wqmm":"04 lần","daff":"2 lần","nkxi":"5 lần","xvyx":"3 lần"',
#   'wqmm',
#   'wqmm',
#   1),
#  ('2',
#   '109',
#   '"zxpm":"Quận, Huyện, Thị uỷ","tqyh":"Tổ chức cơ sở đảng","ojjn":"Chi '
#   'bộ","arnw":"Tỉnh, Thành uỷ"',
#   'ojjn',
#   'ojjn',
#   1),
#  ('24',
#   '131',
#   '"yaln":"6","jnec":"7","zpyb":"8","ibnl":"9"',
#   'zpyb',
#   'zpyb',
#   1),
#  ('28',
#   '135',
#   '"kyha":"Đất nước ta chưa bao giờ có được cơ đồ, vị thế và uy tín quốc tế '
#   'như ngày nay.","fuje":"Đất nước ta chưa bao giờ có được cơ đồ, tiềm lực và '
#   'uy tín quốc tế như ngày nay.","tlai":"Đất nước ta chưa bao giờ có được tiềm '
#   'lực, vị thế và uy tín quốc tế như ngày nay.","hwnk":"Đất nước ta chưa bao '
#   'giờ có được cơ đồ, tiềm lực, vị thế và uy tín quốc tế như ngày nay."',
#   'hwnk',
#   'hwnk',
#   1),
#  ('30',
#   '137',
#   '"nneb":"Ngày 23\\/01\\/2019","mcsy":"Ngày 24\\/01\\/2019","lhvk":"Ngày '
#   '18\\/7\\/2019","gfjj":"Ngày 24\\/01\\/2020"',
# ...

# %%
import mysql.connector as conn

# %%
import traceback
import yaml
from yaml import CLoader as Loader, CDumper as Dumper

# %%
from sqlalchemy import create_engine

# %%
# Read params from yml file
with open("mysql_conn.yaml", "r") as f:
    conf = yaml.load(f, Loader=Loader)
host = conf["mysql"]["host"]
db_name = conf["mysql"]["db_name"]
user = conf["mysql"]["user"]
pwd = conf["mysql"]["pwd"]
if pwd is None:
    pwd = ""
print(host, db_name, user, pwd)
# Out:
# 127.0.0.1 quiz_db root

# %%
table_name = "quiz_result_history"
# host = "127.0.0.1"
# db_name = "quiz_db"
# user = "root"
# pwd = ""
try:
    db_conn = conn.connect(host=host, database=db_name, user=user, passwd=pwd, use_pure=True)
    start_id = 0
    end_id = 4000
    query = f"SELECT * FROM {table_name} WHERE result_id >= {start_id} AND result_id <= {end_id};"
    pdf_history = pd.read_sql(query, db_conn)
except:
    traceback.print_exc()
finally:
    db_conn.close()

# %%
pdf_history.shape
# Out:
# (3546, 4)

# %%
# TODO: quiz is a list of exams???

# %%
pdf_history["quiz_ans"] = pdf_history.apply(
    lambda row: extract_question_answer(row["quiz"], row["answers"]), 
    axis=1
) # ["quiz"], row["answers"]))
display(pdf_history[500:600].head())
print_runtime()
# Out:
#      result_id                                               quiz  \
# 500        568  {"2":{"id":"4","excerpt":"Theo ch\u1ec9 th\u1e...
# 501        569  {"4":{"id":"6","excerpt":"Theo Ch\u1ec9 th\u1e...
# 502        570  {"4":{"id":"6","excerpt":"Theo Ch\u1ec9 th\u1e...
# 503        571  {"0":{"id":"2","excerpt":"T\u1eeb n\u0103m 200...
# 504        572  {"2":{"id":"4","excerpt":"Theo ch\u1ec9 th\u1e...
#
#                                                answers  \
# 500  {"61":["ouwp"],"35":["kofx"],"62":["mjdj"],"95...
# 501  {"88":["xmsv"],"12":["zwmy"],"53":["uhcc"],"8"...
# 502  {"77":["fahu"],"103":["yfdx"],"43":["bgkj"],"8...
# 503  {"28":["hwnk"],"2":["tqyh"],"79":["ekdi"],"101...
# 504  {"104":["vmfv"],"53":["uhcc"],"90":["mwok"],"7...
#
#                                                  essay  \
# 500  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# 501  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# 502  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# ...

# %%
pdf_history["ans_len"] = pdf_history["quiz_ans"].apply(lambda x: len(x))
display(pdf_history[500:600].head())
print_runtime()
# Out:
#      result_id                                               quiz  \
# 500        568  {"2":{"id":"4","excerpt":"Theo ch\u1ec9 th\u1e...
# 501        569  {"4":{"id":"6","excerpt":"Theo Ch\u1ec9 th\u1e...
# 502        570  {"4":{"id":"6","excerpt":"Theo Ch\u1ec9 th\u1e...
# 503        571  {"0":{"id":"2","excerpt":"T\u1eeb n\u0103m 200...
# 504        572  {"2":{"id":"4","excerpt":"Theo ch\u1ec9 th\u1e...
#
#                                                answers  \
# 500  {"61":["ouwp"],"35":["kofx"],"62":["mjdj"],"95...
# 501  {"88":["xmsv"],"12":["zwmy"],"53":["uhcc"],"8"...
# 502  {"77":["fahu"],"103":["yfdx"],"43":["bgkj"],"8...
# 503  {"28":["hwnk"],"2":["tqyh"],"79":["ekdi"],"101...
# 504  {"104":["vmfv"],"53":["uhcc"],"90":["mwok"],"7...
#
#                                                  essay  \
# 500  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# 501  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# 502  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# ...

# %%
pdf_history[pdf_history["ans_len"]==0]
# Out:
#       result_id                                               quiz answers  \
# 2             3  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 3             4  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 4             5  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 5             6  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 6             7  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# ...         ...                                                ...     ...
# 3335       3771  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 3377       3815  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 3383       3822  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 3456       3902  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
# 3528       3980  [{"id":"2","excerpt":"T\u1eeb n\u0103m 2003 \u...      []
#
# ...

# %%
pdf_history_short = pdf_history[[
    "result_id", "essay", "quiz_ans"
    ]].copy()


print_runtime()
# Out:
# 2021-09-19 18:08:29
# -------------------

# %%
def split_choice(ch):
    regex_split_choice = re.compile("\"([a-z]{4})\"")
    return regex_split_choice.findall(str(ch))

# %%
pdf_01 = pdf_history_short.explode(column="quiz_ans").reset_index()
ls_match_col = ["match_id", "question_id", "choice", "correct_ans", "ans", "correct"]
pdf_02 = pd.DataFrame(pdf_01["quiz_ans"].tolist(), index=pdf_01.index, columns=ls_match_col)
pdf_02["list_choice"] = pdf_02["choice"].apply(split_choice)
display(pdf_02.head())
print_runtime()
# Out:
#   match_id question_id                                             choice  \
# 0        1           3  "qsun":"G\u1eafn vi\u1ec7c h\u1ecdc t\u1eadp v...
# 1       14          16  "lgrn":"Trung v\u1edbi n\u01b0\u1edbc, hi\u1eb...
# 2       15          17  "wqpc":"N\u00f3i \u0111i \u0111\u00f4i v\u1edb...
# 3       17          19    "fhwu":"03","amrz":"04","igea":"05","brds":"06"
# 4       20          22    "jxhb":"25","xuir":"26","jtft":"27","euyc":"28"
#
#   correct_ans   ans  correct               list_choice
# 0        pnwt  pnwt      1.0  [qsun, ptpk, bdvm, pnwt]
# 1        guld  guld      1.0  [lgrn, guld, icsy, yimm]
# 2        tdqh  tdqh      1.0  [wqpc, bslh, vezu, tdqh]
# 3        amrz  amrz      1.0  [fhwu, amrz, igea, brds]
# 4        jtft  jtft      1.0  [jxhb, xuir, jtft, euyc]
# 2021-09-19 18:09:37
# -------------------

# %%
pdf_03 = pd.merge(pdf_01, pdf_02, left_index=True, right_index=True)
print(f"pdf_01: {pdf_01.shape}; pdf_02: {pdf_02.shape}; pdf_03: {pdf_03.shape}; ")
display(pdf_03.head())
print_runtime()
# Out:
# pdf_01: (64438, 5); pdf_02: (64438, 7); pdf_03: (64438, 12);
#    index  result_id essay                                           quiz_ans  \
# 0      0          1    []  (1, 3, "qsun":"G\u1eafn vi\u1ec7c h\u1ecdc t\u...
# 1      0          1    []  (14, 16, "lgrn":"Trung v\u1edbi n\u01b0\u1edbc...
# 2      0          1    []  (15, 17, "wqpc":"N\u00f3i \u0111i \u0111\u00f4...
# 3      0          1    []  (17, 19, "fhwu":"03","amrz":"04","igea":"05","...
# 4      0          1    []  (20, 22, "jxhb":"25","xuir":"26","jtft":"27","...
#
#    ans_len match_id question_id  \
# 0       20        1           3
# 1       20       14          16
# 2       20       15          17
# 3       20       17          19
# 4       20       20          22
#
#                                               choice correct_ans   ans  \
# 0  "qsun":"G\u1eafn vi\u1ec7c h\u1ecdc t\u1eadp v...        pnwt  pnwt
# 1  "lgrn":"Trung v\u1edbi n\u01b0\u1edbc, hi\u1eb...        guld  guld
# ...

# %%
pdf03_test = pdf_03.groupby("result_id", as_index=False).agg({
    "correct": "sum"
})
display(pdf03_test.head())
print_runtime()
# Out:
#    result_id  correct
# 0          1     20.0
# 1          2     15.0
# 2          3      0.0
# 3          4      0.0
# 4          5      0.0
# 2021-09-19 18:10:37
# -------------------

# %%
pdf03_test.describe()
# Out:
#          result_id      correct
# count  3546.000000  3546.000000
# mean   2011.605753     9.454879
# std    1160.847628     5.514727
# min       1.000000     0.000000
# 25%     991.500000     5.000000
# 50%    2025.500000     8.000000
# 75%    3014.750000    14.000000
# max    4000.000000    20.000000

# %%
pdf03_test[pdf03_test['correct']==0].shape
# Out:
# (136, 2)

# %%
display(pdf_history_short.head())
print_runtime()

# %%
start_id, end_id
# Out:
# (0, 4000)

# %%
o_path = f"quiz_result_history_{start_id}_{end_id}.pkl"
pdf_03[["result_id", "question_id", "list_choice", "correct_ans", "ans"]].to_pickle(o_path, compression="bz2")
print_runtime()
# Out:
# 2021-09-19 18:11:19
# -------------------

# %% [markdown]
# # Combine all together

# %%
# Read params from yml file
with open("mysql_conn.yaml", "r") as f:
    conf = yaml.load(f, Loader=Loader)
host = conf["mysql"]["host"]
db_name = conf["mysql"]["db_name"]
user = conf["mysql"]["user"]
pwd = conf["mysql"]["pwd"]
if pwd is None:
    pwd = ""
print(host, db_name, user, pwd)

# %%
max_id = 34326
interval = 4000
ls_chunk = [[i*interval, min((i+1)*interval-1, max_id)] for i in range(max_id//interval+1)]
pprint(ls_chunk)
print_runtime()
# Out:
# [[0, 3999],
#  [4000, 7999],
#  [8000, 11999],
#  [12000, 15999],
#  [16000, 19999],
#  [20000, 23999],
#  [24000, 27999],
#  [28000, 31999],
#  [32000, 34326]]
# 2021-09-19 16:56:58
# -------------------

# %%
def extract_question_answer(quiz, answers):
    # quiz = row["quiz"]
    # answers = row["answers"]
    quiz_fmt = 0
    regex = re.compile(
        "\"(\d{1,9})\":\{\"id\":\"(\d{1,9})\",\"excerpt.*?\"answer\":\{(.*?)\},\"true\":\[\"([a-z]{4})"
    )
    regex_ans = re.compile("\"(\d{1,9})\":\[\"([a-z]{4})\"")
    if quiz[0] == "[" and quiz[-1] == "]":
        regex = re.compile(
            "\{\"id\":\"(\d{1,9})\",\"excerpt.*?\"answer\":\{(.*?)\},\"true\":\[\"([a-z]{4})"
        )
        regex_ans = re.compile("\"([a-z]{4})\"")
        quiz_fmt = 1
    ls_match = sorted(regex.findall(quiz), key=lambda tup: int(tup[0]))
    ls_ans = regex_ans.findall(answers)
    if quiz_fmt == 0:
        ls_ans = sorted(ls_ans, key=lambda tup: int(tup[0]))
    if len(ls_ans) == 0:
        ls_ans = [""] * len(ls_match)
    # if len(ls_match) != len(ls_ans):
    #     return []
    ls_output = []
    for match, ans in zip(ls_match, ls_ans):
        # print(match, ans, match[0]==ans[0])
        if quiz_fmt == 0:  # Full quiz
            # Match_id, question_id, choice, correct_ans, ans, correct
            if ans == "":  # Empty ans
                quiz_ans = (match[0], match[1], match[2], match[3], "", 0)
            elif match[0] == ans[0]:  # Full ans
                # Match_id, question_id, choice, correct_ans, ans, correct
                quiz_ans = (match[0], match[1], match[2], match[3], ans[1], 
                            int(match[3]==ans[1]))
        else:  # List of question_id, no match_id
            # Match_id=-1, question_id, choice, correct_ans, ans, correct
            if ans == "":  # Empty ans
                quiz_ans = (-1, match[0], match[1], match[2], "No answer", 0)
            else:  # ans as list of choices, no index
                quiz_ans = (-1, match[0], match[1], match[2], ans, 
                            int(match[2]==ans))

        ls_output.append(quiz_ans)
    # if len(ls_output) != len(ls_match):
    #     return []
    return ls_output

pprint(extract_question_answer(quiz, answers))
print_runtime()
# Out:
# [('0',
#   '107',
#   '"wqmm":"04 lần","daff":"2 lần","nkxi":"5 lần","xvyx":"3 lần"',
#   'wqmm',
#   'wqmm',
#   1),
#  ('2',
#   '109',
#   '"zxpm":"Quận, Huyện, Thị uỷ","tqyh":"Tổ chức cơ sở đảng","ojjn":"Chi '
#   'bộ","arnw":"Tỉnh, Thành uỷ"',
#   'ojjn',
#   'ojjn',
#   1),
#  ('24',
#   '131',
#   '"yaln":"6","jnec":"7","zpyb":"8","ibnl":"9"',
#   'zpyb',
#   'zpyb',
#   1),
#  ('28',
#   '135',
#   '"kyha":"Đất nước ta chưa bao giờ có được cơ đồ, vị thế và uy tín quốc tế '
#   'như ngày nay.","fuje":"Đất nước ta chưa bao giờ có được cơ đồ, tiềm lực và '
#   'uy tín quốc tế như ngày nay.","tlai":"Đất nước ta chưa bao giờ có được tiềm '
#   'lực, vị thế và uy tín quốc tế như ngày nay.","hwnk":"Đất nước ta chưa bao '
#   'giờ có được cơ đồ, tiềm lực, vị thế và uy tín quốc tế như ngày nay."',
#   'hwnk',
#   'hwnk',
#   1),
#  ('30',
#   '137',
#   '"nneb":"Ngày 23\\/01\\/2019","mcsy":"Ngày 24\\/01\\/2019","lhvk":"Ngày '
#   '18\\/7\\/2019","gfjj":"Ngày 24\\/01\\/2020"',
# ...

# %%
quiz1 = ('['
    '{"id":"2",'
    '"excerpt":"T\u1eeb n\u0103m 2003 \u0111\u1ebfn nay \u0110\u1ea3ng ta \u0111\u00e3 bao nhi\u00eau l\u1ea7n ban h\u00e0nh Ch\u1ec9 th\u1ecb v\u1ec1 h\u1ecdc t\u1eadp v\u00e0 l\u00e0m theo B\u00e1c:","image":null,"sound":null,"youtube":null,'
    '"answer":{"wqmm":"04 l\u1ea7n","daff":"2 l\u1ea7n","nkxi":"5 l\u1ea7n","xvyx":"3 l\u1ea7n"},'
    '"true":["wqmm"]}'
']')
ans1 = "[[\"nkxi\"]]"
pprint(extract_question_answer(quiz1, ans1))
print_runtime()
# Out:
# [(-1,
#   '2',
#   '"wqmm":"04 lần","daff":"2 lần","nkxi":"5 lần","xvyx":"3 lần"',
#   'wqmm',
#   'nkxi',
#   0)]
# 2021-09-22 00:35:20
# -------------------

# %%
def split_choice(ch):
    regex_split_choice = re.compile("\"([a-z]{4})\"")
    return regex_split_choice.findall(str(ch))

# %%
try:
    db_conn = conn.connect(host=host, database=db_name, user=user, passwd=pwd, use_pure=True)
    query = f"SELECT MAX(result_id) AS max_id FROM {table_name};"
    pdf_max_id = pd.read_sql(query, db_conn)
except:
    traceback.print_exc()
finally:
    db_conn.close()
max_id = pdf_max_id["max_id"][0]
print(max_id)
interval = 4000
ls_chunk = [[i*interval, min((i+1)*interval-1, max_id)] for i in range(max_id//interval+1)]
pprint(ls_chunk)
print_runtime()
# Out:
# 9999
# [[0, 3999], [4000, 7999], [8000, 9999]]
# 2021-09-22 00:35:27
# -------------------

# %%
ls_output_col = ["result_id", "question_id", "decode_result", "decode_ans"]
ls_extract_col = ["result_id", "question_id", "list_choice", "correct_ans", "ans"]

# %%
ls_result_hist = []
for start_id, end_id in ls_chunk:
    print("#", start_id, "-", end_id)
    table_name = "quiz_result_history"
    # host = "127.0.0.1"
    # db_name = "quiz_db"
    # user = "root"
    # pwd = ""
    try:
        db_conn = conn.connect(host=host, database=db_name, user=user, passwd=pwd, use_pure=True)
        query = f"SELECT * FROM {table_name} WHERE result_id >= {start_id} AND result_id <= {end_id};"
        pdf_history = pd.read_sql(query, db_conn)
    except:
        traceback.print_exc()
    finally:
        db_conn.close()
        
    pdf_history["quiz_ans"] = pdf_history.apply(
        lambda row: extract_question_answer(row["quiz"], row["answers"]), 
        axis=1
    ) # ["quiz"], row["answers"]))
    
    pdf_history_short = pdf_history[[
        "result_id", "essay", "quiz_ans"
    ]].copy()
    pdf_history_short["n_quiz"] = pdf_history_short["quiz_ans"].apply(lambda x: len(x))
    display(pdf_history_short.head())
    print(f"After explode: {sum(pdf_history_short['n_quiz'])}")

    pdf_01 = pdf_history_short.explode(column="quiz_ans").reset_index()
    ls_match_col = ["match_id", "question_id", "choice", "correct_ans", "ans", "correct"]
    pdf_02 = pd.DataFrame(pdf_01["quiz_ans"].tolist(), index=pdf_01.index, columns=ls_match_col)
    pdf_02["list_choice"] = pdf_02["choice"].apply(split_choice)
    pdf_03 = pd.merge(pdf_01, pdf_02, left_index=True, right_index=True)
    print(f"pdf_01: {pdf_01.shape}; pdf_02: {pdf_02.shape}; pdf_03: {pdf_03.shape}; ")

    ls_result_hist.append(pdf_03[ls_extract_col].copy())
    print_runtime()

o_path = "quiz_result_history_1.pkl"
print(f"Write to: {o_path}")
pdf_result_hist = pd.concat(ls_result_hist).reset_index()
pdf_result_hist.to_pickle(o_path, compression="bz2")
# Out:
# # 0 - 3999
#    result_id                                              essay  \
# 0          1                                                 []
# 1          2                                                 []
# 2          3                                                 []
# 3          4  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
# 4          5  {"xcnr":{"limit":"10","excerpt":"H\u00e3y cho ...
#
#                                             quiz_ans  n_quiz
# 0  [(1, 3, "qsun":"G\u1eafn vi\u1ec7c h\u1ecdc t\...      20
# 1  [(5, 7, "nxsn":"Do c\u1ea5p \u1ee7y c\u00e1c c...      20
# 2  [(-1, 2, "wqmm":"04 l\u1ea7n","daff":"2 l\u1ea...     105
# 3  [(-1, 2, "wqmm":"04 l\u1ea7n","daff":"2 l\u1ea...     105
# 4  [(-1, 2, "wqmm":"04 l\u1ea7n","daff":"2 l\u1ea...     105
# After explode: 71594
# pdf_01: (71594, 5); pdf_02: (71594, 7); pdf_03: (71594, 12);
# 2021-09-22 00:36:53
# -------------------
# # 4000 - 7999
# ...

# %%
list_choice = ['qsun', 'ptpk', 'bdvm', 'pnwt']
ans = "pnt"
# print(list_choice[1:-1].find(ans)//8)
try:
    print(list_choice.index(ans))
except ValueError as e:
    print(e)
# Out:
# 'pnt' is not in list

# %%
def decode_answer(list_choice, ans):
    if not isinstance(ans, str) or len(ans) != 4: 
        return "error"
    # idx = list_choice[1:-1].find(ans)//7
    idx = list_choice.index(ans)
    if idx < 0:
        return "error"

    return "ABCDEFGH"[idx]

print(decode_answer(list_choice, ans))
print_runtime()
# Out:
# D
# 2021-09-22 00:37:14
# -------------------

# %%
pdf_result_hist["decode_result"] = pdf_result_hist.apply(
    lambda x: decode_answer(x["list_choice"], x["correct_ans"]), axis=1)
pdf_result_hist["decode_ans"] = pdf_result_hist.apply(
    lambda x: decode_answer(x["list_choice"], x["ans"]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-d28c94a779f9> in <module>()
#       1 pdf_result_hist["decode_result"] = pdf_result_hist.apply(
# ----> 2     lambda x: decode_answer(x["list_choice"], x["correct_ans"]), axis=1)
#       3 pdf_result_hist["decode_ans"] = pdf_result_hist.apply(
#       4     lambda x: decode_answer(x["list_choice"], x["ans"]), axis=1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
# ...

# %%
pdf_result_hist.head()
# Out:
#    index  result_id question_id                       list_choice correct_ans  \
# 0      0          1           3  ['qsun', 'ptpk', 'bdvm', 'pnwt']        pnwt
# 1      1          1          16  ['lgrn', 'guld', 'icsy', 'yimm']        guld
# 2      2          1          17  ['wqpc', 'bslh', 'vezu', 'tdqh']        tdqh
# 3      3          1          19  ['fhwu', 'amrz', 'igea', 'brds']        amrz
# 4      4          1          22  ['jxhb', 'xuir', 'jtft', 'euyc']        jtft
#
#     ans decode_result decode_ans
# 0  pnwt             D          D
# 1  guld             B          B
# 2  tdqh             D          D
# 3  amrz             B          B
# 4  jtft             C          C

# %% [markdown]
# # Write to db

# %%
try:
    # db_conn = conn.connect(host=host, database=db_name, user=user, passwd=pwd, use_pure=True)
    conn_str = f"mysql+pymysql://{user}:{pwd}@{host}/{db_name}"
    engine = create_engine(conn_str)
    pdf_result_hist[ls_output_col].to_sql(
        "quiz_result_history_1", con=engine, 
        if_exists="replace", chunksize=1000, index=False)
except:
    traceback.print_exc()

# %%
pdf_result_hist.dtypes
# Out:
# index             int64
# result_id         int64
# question_id      object
# list_choice      object
# correct_ans      object
# ans              object
# decode_result    object
# decode_ans       object
# dtype: object

# %%
pdf_result_hist[
    (pdf_result_hist["result_id"]==1241)
    # & (pdf_result_hist["result_id"]<=8025) 
]
# Out:
# Empty DataFrame
# Columns: [index, result_id, question_id, list_choice, correct_ans, ans]
# Index: []
